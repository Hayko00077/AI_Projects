# %% [markdown]
# <a href="https://colab.research.google.com/github/Hayko00077/AI_Projects/blob/main/Hayk_Vardazaryan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/data_retake.csv')
print(df.shape)
print(df.columns)
df.describe()
df.info()
df.head(10)
# Out:
# (10000, 11)
# Index(['Unnamed: 0', 'College_ID', 'IQ', 'Prev_Sem_Result', 'CGPA',
#        'Academic_Performance', 'Internship_Experience',
#        'Extra_Curricular_Score', 'Communication_Skills', 'Projects_Completed',
#        'Placement'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              10000 non-null  int64
#  1   College_ID              9516 non-null   object
#  2   IQ                      9448 non-null   object
#  3   Prev_Sem_Result         9444 non-null   object
#  4   CGPA                    9455 non-null   object
#  5   Academic_Performance    9463 non-null   object
#  6   Internship_Experience   9517 non-null   object
#  7   Extra_Curricular_Score  9464 non-null   object
#  8   Communication_Skills    9468 non-null   object
# ...

# %%
print(df.isna().sum())
print(f"Number of duplicatdf {df.duplicated().sum()}")
# Out:
# Unnamed: 0                  0
# College_ID                484
# IQ                        552
# Prev_Sem_Result           556
# CGPA                      545
# Academic_Performance      537
# Internship_Experience     483
# Extra_Curricular_Score    536
# Communication_Skills      532
# Projects_Completed        559
# Placement                 488
# dtype: int64
# Number of duplicatdf 0

# %%
missing_data = df.isnull().sum()
missing_percentage = (missing_data / len(df)) * 100

missing_df = pd.DataFrame({
    'Column': missing_data.index,
    'Missing Count': missing_data.values,
    'Missing Percentage': missing_percentage.values
}).sort_values('Missing Percentage', ascending=False)
print(" Missing Values Summary:")
print("-" * 30)
display(missing_df)
# Out:
#  Missing Values Summary:
# ------------------------------
#                     Column  Missing Count  Missing Percentage
# 9       Projects_Completed            559                5.59
# 3          Prev_Sem_Result            556                5.56
# 2                       IQ            552                5.52
# 4                     CGPA            545                5.45
# 5     Academic_Performance            537                5.37
# 7   Extra_Curricular_Score            536                5.36
# 8     Communication_Skills            532                5.32
# 10               Placement            488                4.88
# 1               College_ID            484                4.84
# 6    Internship_Experience            483                4.83
# 0               Unnamed: 0              0                0.00

# %%
df['College_ID'].unique()
# Out:
# array(['CLG0030', 'CLG0061', 'CLG0036', 'CLG0055', 'CLG0004', 'CLG0015',
#        nan, 'CLG0096', 'CLG0097', 'CLG0057', 'CLG0063', 'CLG0077',
#        'CLG0064', 'CLG0017', 'CLG0053', 'CLG0040', 'CLG0070', 'CLG0050',
#        'CLG0068', 'CLG0072', 'CLG0034', 'CLG0087', 'CLG0073', 'CLG0024',
#        'CLG0008', 'CLG0025', 'CLG0018', 'CLG0014', 'CLG0006', 'CLG0082',
#        'CLG0090', "'(", 'CLG0075', 'CLG0094', '=$', 'CLG0016', 'CLG0076',
#        'CLG0047', 'CLG0054', 'CLG0058', 'CLG0100', 'CLG0001', 'CLG0041',
#        'CLG0093', 'CLG0027', 'CLG0062', 'CLG0081', 'CLG0028', 'CLG0020',
#        'CLG0051', 'CLG0069', 'CLG0088', 'CLG0038', 'CLG0029', 'CLG0035',
#        'CLG0019', 'CLG0005', 'CLG0026', 'CLG0066', 'CLG0043', 'CLG0074',
#        'CLG0048', 'CLG0012', 'CLG0099', 'CLG0011', 'CLG0091', 'CLG0089',
#        'CLG0083', 'CLG0080', 'CLG0044', '++', 'CLG0059', 'CLG0031',
#        'CLG0039', 'CLG0065', 'CLG0079', 'CLG0095', 'CLG0085', 'CLG0033',
# ...

# %%
df['College_ID'] = df['College_ID'].replace(['@', '??', '_', '#', "'(", '//', '|:', '@]', ',=', '`(', ']{', '&`', '--', ':+', '.]', '~#',
       '(:', 'CLG0052', '/^', "'^", '@,', '<<', '/&', '[?', "~'", '-[',
       '%@', '+.', ']+', '+*', '/#', '#*', '[+', '<)', '`>', '=/', '?"',
       "['", ']}', '_~', '_!', '~]', '&\\', '#:', '\\_', "'`", '~<', '.|',
       '!]', '`*', "'&", '|#', '%=', ',!', '<`', '\'"', '`!', '\\@',
       '\\$', '-<', '>|', '&(', '|+', '}?', '@@', '}#', '{#', '-&', '|`',
       ':[', '*_', '/(', '^{', '="', '.-', '<{', '$^', '[,', '<-', '`{',
       '"%', '-=', '+?', '?]', '<?', '<$', ']%', '$/', '^.', '}.', ')?',
       '#{', '.#', '^*', '}\\', '+#', ':)', '~&', '*:', '`"', '^/', '!}',
       '"(', '-}', ',@', '{*', '[~', '\\]', '|/', '-#', '@"', '|!', '@)',
       '(%', '`=', "'_", '$_', '<+', '_)', '.^', '"&', '["', ',\\', '^,',
       '"+', '.~', ').', '${', '}^', '{.', '%|', '-_', '&+', '_(', '_\\',
       "'\\", '%[', '][', '(}', '<.', ',{', '\\|', '."', '+)', '+|', ',#',
       '`[', '+$', ')#', '{{', '>[', '.>', '+{', '[!', '"#', '>&', "'!",
       '~;', '@:', '-?', "''", '[@', '"=', '?^', ',|', '?\\', "'<", '$|',
       '+^', '`|', '@^', '>#', '(/', "^'", '~.', '.=', '(|', '?~', '|\\',
       '((', '(^', '(_', '-$', '(&', '~!', '&.', '%+', ';!', "('", '{<',
       '&|', '&>', '$;', ']|', ':#', '\\{', '_>', '.?', '+,', '`:', '~-',
       '}"', '|}', '"?', '{&', '$[', '!!', '/;', '^_', ':=', "\\'", '\\+',
       ';]', '*%', '<|', '+<', '@;', '&$', '*&', '&~', '+;', ')|', '_=',
       '\\-', '):', '.`', '`?', '|~', '-/', ',-', '?;', '_,', '<\\', "*'",
       '#|', '#,', '{>', '({', '@+', ':"', '?&', '#@', '?}', '|$', '"<',
       '=;', "'~", ']?', ':,', '"\\', '%`', '%$', '@%', '),', ';-', '%)',
       ',[', '++', '\\}', "_'", '\\}', '&)', '_&', '};', '?*', '?$', '+>', '?.', '=$'], np.nan)
df['College_ID'].unique()
# Out:
# array(['CLG0030', 'CLG0061', 'CLG0036', 'CLG0055', 'CLG0004', 'CLG0015',
#        nan, 'CLG0096', 'CLG0097', 'CLG0057', 'CLG0063', 'CLG0077',
#        'CLG0064', 'CLG0017', 'CLG0053', 'CLG0040', 'CLG0070', 'CLG0050',
#        'CLG0068', 'CLG0072', 'CLG0034', 'CLG0087', 'CLG0073', 'CLG0024',
#        'CLG0008', 'CLG0025', 'CLG0018', 'CLG0014', 'CLG0006', 'CLG0082',
#        'CLG0090', 'CLG0075', 'CLG0094', 'CLG0016', 'CLG0076', 'CLG0047',
#        'CLG0054', 'CLG0058', 'CLG0100', 'CLG0001', 'CLG0041', 'CLG0093',
#        'CLG0027', 'CLG0062', 'CLG0081', 'CLG0028', 'CLG0020', 'CLG0051',
#        'CLG0069', 'CLG0088', 'CLG0038', 'CLG0029', 'CLG0035', 'CLG0019',
#        'CLG0005', 'CLG0026', 'CLG0066', 'CLG0043', 'CLG0074', 'CLG0048',
#        'CLG0012', 'CLG0099', 'CLG0011', 'CLG0091', 'CLG0089', 'CLG0083',
#        'CLG0080', 'CLG0044', 'CLG0059', 'CLG0031', 'CLG0039', 'CLG0065',
#        'CLG0079', 'CLG0095', 'CLG0085', 'CLG0033', 'CLG0007', 'CLG0037',
# ...

# %%
df['IQ'].unique()
# Out:
# array(['107.0', '97.0', nan, '96.0', '123.0', '111.0', '92.0', '108.0',
#        '93.0', '103.0', '71.0', '74.0', '91.0', '84.0', '104.0', '86.0',
#        '78.0', '121.0', '101.0', '82.0', '105.0', '90.0', '95.0', '127.0',
#        '99.0', '112.0', '81.0', '70.0', '102.0', '98.0', '77.0', '89.0',
#        '73.0', '94.0', '109.0', '115.0', '87.0', '114.0', '83.0', '120.0',
#        '60.0', '122.0', '113.0', '100.0', '106.0', '136.0', '117.0', '#',
#        '85.0', '76.0', '88.0', '119.0', '75.0', '80.0', '128.0', '140.0',
#        '116.0', '79.0', '157.0', '134.0', '110.0', '132.0', '69.0',
#        '126.0', '131.0', '??', '51.0', '124.0', '@', '68.0', '118.0',
#        '130.0', '129.0', '65.0', '146.0', '125.0', '_', '72.0', '62.0',
#        '66.0', '59.0', '139.0', '138.0', '137.0', '67.0', '63.0', '56.0',
#        '133.0', '61.0', '64.0', '147.0', '55.0', '54.0', '141.0', '135.0',
#        '144.0', '58.0', '158.0', '57.0', '143.0', '148.0', '142.0',
# ...

# %%
df['IQ'] = df['IQ'].replace(['@', '??', '_', '#'], np.nan)
df['IQ'].unique()
# Out:
# array(['107.0', '97.0', nan, '96.0', '123.0', '111.0', '92.0', '108.0',
#        '93.0', '103.0', '71.0', '74.0', '91.0', '84.0', '104.0', '86.0',
#        '78.0', '121.0', '101.0', '82.0', '105.0', '90.0', '95.0', '127.0',
#        '99.0', '112.0', '81.0', '70.0', '102.0', '98.0', '77.0', '89.0',
#        '73.0', '94.0', '109.0', '115.0', '87.0', '114.0', '83.0', '120.0',
#        '60.0', '122.0', '113.0', '100.0', '106.0', '136.0', '117.0',
#        '85.0', '76.0', '88.0', '119.0', '75.0', '80.0', '128.0', '140.0',
#        '116.0', '79.0', '157.0', '134.0', '110.0', '132.0', '69.0',
#        '126.0', '131.0', '51.0', '124.0', '68.0', '118.0', '130.0',
#        '129.0', '65.0', '146.0', '125.0', '72.0', '62.0', '66.0', '59.0',
#        '139.0', '138.0', '137.0', '67.0', '63.0', '56.0', '133.0', '61.0',
#        '64.0', '147.0', '55.0', '54.0', '141.0', '135.0', '144.0', '58.0',
#        '158.0', '57.0', '143.0', '148.0', '142.0', '52.0', '152.0',
# ...

# %%
df['Prev_Sem_Result'].unique()
# Out:
# array(['6.61', '5.52', '5.36', '5.47', '7.91', '5.26', '6.68', '8.77',
#        '6.47', '8.82', '8.73', '6.23', '8.64', '8.74', nan, '6.05',
#        '7.61', '9.61', '8.2', '5.86', '8.41', '7.14', '7.96', '8.67',
#        '7.57', '9.07', '8.61', '8.08', '5.75', '9.18', '9.68', '5.68',
#        '7.44', '6.29', '5.7', '9.39', '5.9', '8.99', '7.28', '6.64',
#        '5.79', '5.84', '8.31', '7.75', '5.61', '5.56', '8.72', '8.56',
#        '5.29', '7.8', '5.42', '9.54', '8.49', '9.63', '9.14', '7.85',
#        '6.53', '6.09', '8.14', '7.34', '6.17', '7.94', '9.62', '8.33',
#        '5.93', '9.47', '6.24', '5.46', '#', '5.88', '6.86', '5.14',
#        '5.69', '5.27', '8.28', '6.87', '9.37', '6.07', '8.1', '7.1',
#        '8.07', '8.81', '6.5', '6.8', '8.59', '8.06', '5.89', '6.88',
#        '7.41', '8.4', '6.25', '7.71', '9.0', '5.18', '9.92', '7.27',
#        '6.46', '5.87', '8.96', '9.78', '7.07', '9.76', '9.12', '8.37',
# ...

# %%
df['Prev_Sem_Result'] = df['Prev_Sem_Result'].replace(['@', '??', '_', '#'], np.nan)
df['Prev_Sem_Result'].unique()
# Out:
# array(['6.61', '5.52', '5.36', '5.47', '7.91', '5.26', '6.68', '8.77',
#        '6.47', '8.82', '8.73', '6.23', '8.64', '8.74', nan, '6.05',
#        '7.61', '9.61', '8.2', '5.86', '8.41', '7.14', '7.96', '8.67',
#        '7.57', '9.07', '8.61', '8.08', '5.75', '9.18', '9.68', '5.68',
#        '7.44', '6.29', '5.7', '9.39', '5.9', '8.99', '7.28', '6.64',
#        '5.79', '5.84', '8.31', '7.75', '5.61', '5.56', '8.72', '8.56',
#        '5.29', '7.8', '5.42', '9.54', '8.49', '9.63', '9.14', '7.85',
#        '6.53', '6.09', '8.14', '7.34', '6.17', '7.94', '9.62', '8.33',
#        '5.93', '9.47', '6.24', '5.46', '5.88', '6.86', '5.14', '5.69',
#        '5.27', '8.28', '6.87', '9.37', '6.07', '8.1', '7.1', '8.07',
#        '8.81', '6.5', '6.8', '8.59', '8.06', '5.89', '6.88', '7.41',
#        '8.4', '6.25', '7.71', '9.0', '5.18', '9.92', '7.27', '6.46',
#        '5.87', '8.96', '9.78', '7.07', '9.76', '9.12', '8.37', '7.17',
# ...

# %%
df['Academic_Performance'].unique()
# Out:
# array(['8.0', '9.0', '6.0', '7.0', '5.0', '4.0', '2.0', '3.0', '10.0',
#        '1.0', '@', nan, '#', '??', '_'], dtype=object)

# %%
df['Academic_Performance'] = df['Academic_Performance'].replace(['@', '??', '_', '#'], np.nan)
df['Academic_Performance'].unique()
# Out:
# array(['8.0', '9.0', '6.0', '7.0', '5.0', '4.0', '2.0', '3.0', '10.0',
#        '1.0', nan], dtype=object)

# %%
df['CGPA'].unique()
# Out:
# array(['6.28', '5.37', '5.83', '5.75', '7.69', '5.32', '6.58', '8.76',
#        '6.33', '8.6', nan, '6.51', '9.01', '8.4', '7.31', '7.54', '10.01',
#        '8.15', '5.56', '8.07', '7.11', '_', '@', '7.86', '9.45', '8.86',
#        '8.48', '5.33', '9.61', '9.58', '6.1', '7.02', '9.11', '5.97',
#        '9.27', '5.96', '6.98', '6.39', '5.51', '5.89', '8.72', '8.16',
#        '5.16', '5.14', '#', '5.18', '7.89', '5.5', '9.56', '9.38', '8.7',
#        '9.96', '8.91', '8.73', '7.65', '6.17', '6.06', '6.3', '8.1',
#        '5.58', '6.53', '6.87', '6.22', '9.12', '8.5', '7.6', '6.04',
#        '9.44', '6.16', '5.85', '5.78', '6.69', '5.41', '6.11', '5.57',
#        '8.77', '9.39', '7.12', '9.85', '6.76', '5.99', '8.52', '7.48',
#        '9.26', '7.77', '9.19', '6.54', '6.74', '8.54', '7.96', '6.31',
#        '7.7', '7.5', '9.57', '9.07', '7.62', '8.23', '9.09', '5.44', '??',
#        '7.46', '7.23', '9.6', '10.17', '6.92', '8.66', '6.96', '7.3',
# ...

# %%
df['CGPA'] = df['CGPA'].replace(['@', '??', '_', '#'], np.nan)
df['CGPA'].unique()
# Out:
# array(['6.28', '5.37', '5.83', '5.75', '7.69', '5.32', '6.58', '8.76',
#        '6.33', '8.6', nan, '6.51', '9.01', '8.4', '7.31', '7.54', '10.01',
#        '8.15', '5.56', '8.07', '7.11', '7.86', '9.45', '8.86', '8.48',
#        '5.33', '9.61', '9.58', '6.1', '7.02', '9.11', '5.97', '9.27',
#        '5.96', '6.98', '6.39', '5.51', '5.89', '8.72', '8.16', '5.16',
#        '5.14', '5.18', '7.89', '5.5', '9.56', '9.38', '8.7', '9.96',
#        '8.91', '8.73', '7.65', '6.17', '6.06', '6.3', '8.1', '5.58',
#        '6.53', '6.87', '6.22', '9.12', '8.5', '7.6', '6.04', '9.44',
#        '6.16', '5.85', '5.78', '6.69', '5.41', '6.11', '5.57', '8.77',
#        '9.39', '7.12', '9.85', '6.76', '5.99', '8.52', '7.48', '9.26',
#        '7.77', '9.19', '6.54', '6.74', '8.54', '7.96', '6.31', '7.7',
#        '7.5', '9.57', '9.07', '7.62', '8.23', '9.09', '5.44', '7.46',
#        '7.23', '9.6', '10.17', '6.92', '8.66', '6.96', '7.3', '5.59',
# ...

# %%
df['Internship_Experience'].unique()
# Out:
# array(['No', 'Yes', nan, '!\\', ')%', "'&", ')-', '?_', '(&', '::', ')>',
#        '(]', '),', '~<', '?-', '{}', '"+', '*+', '/_', '<}', '~}', '?=',
#        ';"', '_%', '>\\', '#.', '_}', '*"', '*<', '$#', '%`', '+*', '^{',
#        '*=', '*`', ')?', ']\\', '/]', '|{', '(>', '.(', '-.', "|'", '.}',
#        '=`', '_<', '-_', '|^', '"-', '?"', '%&', '`{', '\\&', '&:', ')=',
#        '\\]', '>(', '`#', '`$', '_>', '<]', '/~', '~_', '>"', '`}', '?.',
#        '+[', '^!', '@@', '`)', '\\*', '*@', '|=', '{-', '#(', '.`', '`/',
#        '?|', '#!', '"&', '&!', "?'", '-,', '"~', '>[', ')@', '?<', "';",
#        ',@', '^_', "')", '+:', '/}', "'%", '#%', '<-', '(.', ".'", '|)',
#        '}_', '#<', '?%', "'-", '!!', '{~', '}@', '!.', '}{', '\\[', ';(',
#        '}.', '/-', '{*', ';\\', '%~', '|]', '*-', ':-', '{.', '[?', '`:',
#        '(\\', '}(', '&@', '\\)', '`-', '`[', ';^', '+{', ':;', ',\\',
#        ']{', '!]', '(#', '\\(', '):', '|&', "'(", '^}', '|,', '[^', '.@',
# ...

# %%
df['Internship_Experience'] = df['Internship_Experience'].replace(['!\\', ')%', "'&", ')-', '?_', '(&', '::', ')>',
       '(]', '),', '~<', '?-', '{}', '"+', '*+', '/_', '<}', '~}', '?=',
       ';"', '_%', '>\\', '#.', '_}', '*"', '*<', '$#', '%`', '+*', '^{',
       '*=', '*`', ')?', ']\\', '/]', '|{', '(>', '.(', '-.', "|'", '.}',
       '=`', '_<', '-_', '|^', '"-', '?"', '%&', '`{', '\\&', '&:', ')=',
       '\\]', '>(', '`#', '`$', '_>', '<]', '/~', '~_', '>"', '`}', '?.',
       '+[', '^!', '@@', '`)', '\\*', '*@', '|=', '{-', '#(', '.`', '`/',
       '?|', '#!', '"&', '&!', "?'", '-,', '"~', '>[', ')@', '?<', "';",
       ',@', '^_', "')", '+:', '/}', "'%", '#%', '<-', '(.', ".'", '|)',
       '}_', '#<', '?%', "'-", '!!', '{~', '}@', '!.', '}{', '\\[', ';(',
       '}.', '/-', '{*', ';\\', '%~', '|]', '*-', ':-', '{.', '[?', '`:',
       '(\\', '}(', '&@', '\\)', '`-', '`[', ';^', '+{', ':;', ',\\',
       ']{', '!]', '(#', '\\(', '):', '|&', "'(", '^}', '|,', '[^', '.@',
       '{?', "='", '}$', '>)', '{;', '(_', '"[', '(<', ':+', '<"', '|-',
       '}-', ':)', '.=', '[$', '%+', '*)', '>,', '~,', '^~', '#:', "#'",
       '$}', '&+', '=)', '){', ')*', ')$', '`\\', '@)', ";'", '.;', '(!',
       '__', '~$', '{{', '$<', '[\\', "`'", '$`', '.%', '-[', '@:', '^<',
       '*%', '+,', '[;', '@]', '{%', '",', '"`', '$]', '|$', '\\=', '(%',
       '>=', '-~', '#}', '?/', '\\/', '@^', ']|', '>>', '\\%', '\\>',
       '=_', '?#', '%?', '=&', '[<', "_'", '}~', '~?', '><', '\\{', '~.',
       '?)', '=:', '%_', "'~", ',|', "'@", '!$', '^+', '|;', '_^', "\\'",
       "~'", '}/', '~#', '`;', '{&', '~!', '#`', '=?', '}"', '@_', '&*',
       '[/', "&'", '(-', '+-', '%)', ':>', '\\}', '([', '+^', ';*', ']%',
       '={', '{`', "@'", ")'", '%#', '$/', '/;', '$*', '/@', '?{', '/.',
       '-;'], np.nan)
df['Internship_Experience'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['Extra_Curricular_Score'].unique()
# Out:
# array(['8.0', nan, '3.0', '1.0', '5.0', '7.0', '0.0', '4.0', '9.0', '2.0',
#        '10.0', '_', '6.0', '??', '@', '#'], dtype=object)

# %%
df['Extra_Curricular_Score'] = df['Extra_Curricular_Score'].replace(['@', '??', '_', '#'], np.nan)
df['Extra_Curricular_Score'].unique()
# Out:
# array(['8.0', nan, '3.0', '1.0', '5.0', '7.0', '0.0', '4.0', '9.0', '2.0',
#        '10.0', '6.0'], dtype=object)

# %%
df['Communication_Skills'].unique()
# Out:
# array(['8.0', nan, '1.0', '6.0', '_', '9.0', '7.0', '5.0', '2.0', '10.0',
#        '3.0', '4.0', '??', '@', '#'], dtype=object)

# %%
df['Communication_Skills'] = df['Communication_Skills'].replace(['@', '??', '_', '#'], np.nan)
df['Communication_Skills'].unique()
# Out:
# array(['8.0', nan, '1.0', '6.0', '9.0', '7.0', '5.0', '2.0', '10.0',
#        '3.0', '4.0'], dtype=object)

# %%
df['Projects_Completed'].unique()
# Out:
# array(['4.0', '0.0', '1.0', '2.0', nan, '#', '??', '3.0', '5.0', '@', '_'],
#       dtype=object)

# %%
df['Projects_Completed'] = df['Projects_Completed'].replace(['@', '??', '_', '#'], np.nan)
df['Projects_Completed'].unique()
# Out:
# array(['4.0', '0.0', '1.0', '2.0', nan, '3.0', '5.0'], dtype=object)

# %%
df['Placement'].unique()
# Out:
# array(['No', 'Yes', ';]', '^{', '/[', nan, '.]', '$_', ']~', '~>', "'@",
#        '%=', ')?', '"\\', '"}', '$$', '|+', '$@', ',;', '{|', '(:', '/}',
#        '>)', "''", '.#', '*)', "'{", '$(', '/+', '~\\', '+`', '>#', '?}',
#        '.-', '*&', '><', '"_', "'&", '@\\', "'=", '?`', '`+', '|[', '\\[',
#        ':+', ':!', '[\\', '^%', '~!', '}\\', '\\`', '+@', '"+', '[=',
#        '!:', '**', '#_', '#/', '~-', '/@', '!=', ";'", '?.', '([', '_!',
#        ';{', ',[', '.^', '?!', '*!', ')"', '?*', '+-', '|~', '[/', "#'",
#        '&[', "':", '@@', '#:', '*^', '|"', '%}', '<?', '!!', '}|', ':_',
#        '<!', ';:', '<"', "'>", '\\$', '|(', "/'", '.}', '@*', '>]', '"<',
#        '&&', ']<', '*`', '!,', "'_", '%^', '[}', '=|', ']#', '@<', '*}',
#        '@.', ',}', '):', ',~', '_.', ':(', '"%', '*{', '"[', '^-', ';,',
#        '\\{', '[+', '&^', '!>', '~;', '!_', '^#', ';)', '$+', '*(', ';%',
#        '*@', '+/', '=$', '];', '({', '}]', '}&', '#[', '(&', '>-', '`#',
# ...

# %%
df['Placement'] = df['Placement'].replace(['.]', '$_', ']~', '~>', "'@",
       '%=', ')?', '"\\', '"}', '$$', '|+', '$@', ',;', '{|', '(:', '/}',
       '>)', "''", '.#', '*)', "'{", '$(', '/+', '~\\', '+`', '>#', '?}',
       '.-', '*&', '><', '"_', "'&", '@\\', "'=", '?`', '`+', '|[', '\\[',
       ':+', ':!', '[\\', '^%', '~!', '}\\', '\\`', '+@', '"+', '[=',
       '!:', '**', '#_', '#/', '~-', '/@', '!=', ";'", '?.', '([', '_!',
       ';{', ',[', '.^', '?!', '*!', ')"', '?*', '+-', '|~', '[/', "#'",
       '&[', "':", '@@', '#:', '*^', '|"', '%}', '<?', '!!', '}|', ':_',
       '<!', ';:', '<"', "'>", '\\$', '|(', "/'", '.}', '@*', '>]', '"<',
       '&&', ']<', '*`', '!,', "'_", '%^', '[}', '=|', ']#', '@<', '*}',
       '@.', ',}', '):', ',~', '_.', ':(', '"%', '*{', '"[', '^-', ';,',
       '\\{', '[+', '&^', '!>', '~;', '!_', '^#', ';)', '$+', '*(', ';%',
       '*@', '+/', '=$', '];', '({', '}]', '}&', '#[', '(&', '>-', '`#',
       '||', '~*', '$*', ']&', '";', ')_', '>_', '=*', '`;', ':"', "'?",
       '/-', '.?', "|'", '/=', '-|', "')", '$]', '?,', '>}', ';!', '/%',
       '.&', '<_', '}!', '^=', '|>', '\\-', ']:', '<-', '$~', '"@', '//',
       '->', '^`', '#{', '/>', '{)', '@`', '*,', '#%', '\\}', '/:', '%%',
       '=~', '?\\', '/"', '%+', '+"', '&!', '~+', '&/', '#,', '<~', ',"',
       '`_', ';_', '_)', ',_', '-%', '."', '<]', '_=', '`<', '_+', '#.',
       '<%', ".'", '-!', "'*", '_<', '>!', '=;', '+<', "?'", '!"', '<{',
       '$&', ':,', '=)', '&{', '%:', ':\\', '+>', '["', ':;', '+|', '@>',
       '{~', '/^', ':?', '-#', '!;', '^@', '!@', '\\?', '##', '}=', '+[',
       '@%', '"=', '?"', '-,', ']>', ';-', ',/', '!`', '#;', '(]', '~,',
       '.;', ';>', '_]', '":', '!^', '^$', '}`', '\\\\', ',>', '&<', '/&',
       '&}', '*[', ';<', '*_', '+$', '=,', '"|', '{#', ';^',';]', '^{', '/['], np.nan)
df['Placement'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
print(df.isna().sum())
df['IQ']
# Out:
# Unnamed: 0                  0
# College_ID                870
# IQ                        789
# Prev_Sem_Result           788
# CGPA                      783
# Academic_Performance      779
# Internship_Experience     783
# Extra_Curricular_Score    783
# Communication_Skills      786
# Projects_Completed        783
# Placement                 788
# dtype: int64
# 0       107.0
# 1        97.0
# 2         NaN
# 3         NaN
# 4        96.0
#         ...
# 9995    119.0
# 9996     70.0
# 9997     89.0
# 9998    107.0
# 9999    109.0
# Name: IQ, Length: 10000, dtype: object

# %%
categorical_cols = df.select_dtypes(include='object').columns

for col in categorical_cols:
    plt.figure(figsize=(5,3))
    sns.countplot(y=df[col])
    plt.title(f'Count of {col}')
    plt.show()

# %%
df.drop(columns=['College_ID'], inplace=True)

# %%
df['IQ'] = pd.to_numeric(df['IQ'], errors='coerce')
median_IQ = df['IQ'].median()
df['IQ'] = df['IQ'].fillna(median_IQ)

# %%
df['Prev_Sem_Result'] = pd.to_numeric(df['Prev_Sem_Result'], errors='coerce')
median_Prev_Sem_Result = df['Prev_Sem_Result'].median()
df['Prev_Sem_Result'] = df['Prev_Sem_Result'].fillna(median_IQ)

# %%
df['Academic_Performance'] = pd.to_numeric(df['Academic_Performance'], errors='coerce')
median_Academic_Performance = df['Academic_Performance'].median()
df['Academic_Performance'] = df['Academic_Performance'].fillna(median_IQ)

# %%
df['CGPA'] = pd.to_numeric(df['CGPA'], errors='coerce')
median_CGPA = df['CGPA'].median()
df['CGPA'] = df['CGPA'].fillna(median_IQ)

# %%
if df['Internship_Experience'].notna().any():
    mode_value = df['Internship_Experience'].mode()[0]
else:
    mode_value = 0

df['Internship_Experience'] = df['Internship_Experience'].fillna(mode_value)
df['Internship_Experience'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Extra_Curricular_Score'] = pd.to_numeric(df['Extra_Curricular_Score'], errors='coerce')
median_Extra_Curricular_Score = df['Extra_Curricular_Score'].median()
df['Extra_Curricular_Score'] = df['Extra_Curricular_Score'].fillna(median_IQ)

# %%
df['Communication_Skills'] = pd.to_numeric(df['Communication_Skills'], errors='coerce')
median_Communication_Skills = df['Communication_Skills'].median()
df['Communication_Skills'] = df['Communication_Skills'].fillna(median_IQ)

# %%
df['Projects_Completed'] = pd.to_numeric(df['Projects_Completed'], errors='coerce')
median_Projects_Completed = df['Projects_Completed'].median()
df['Projects_Completed'] = df['Projects_Completed'].fillna(median_IQ)

# %%
if df['Placement'].notna().any():
    mode_value = df['Placement'].mode()[0]
else:
    mode_value = 0

df['Placement'] = df['Placement'].fillna(mode_value)
df['Placement'].isna().sum()
# Out:
# np.int64(0)

# %%
numeric_cols = df.select_dtypes(include='number').columns

for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.show()

# %%
df[numeric_cols].skew().sort_values()


sns.pairplot(df[numeric_cols])
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.heatmap(df[numeric_cols].corr(), annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
print(" NUMERICAL VARIABLES ANALYSIS")
print("=" * 50)

numeric_columns = df.select_dtypes(include=['int64', 'float64']).columns
df_numeric = df.copy()

for col in numeric_columns:
  plt.figure(figsize=(8, 6))
  df_numeric.boxplot(column=col)
  plt.title(f'Box Plot of {col}')
  plt.show()


print("\n OUTLIER DETECTION (IQR Method):")
print("-" * 30)
for col in numeric_columns:
    Q1 = df_numeric[col].quantile(0.25)
    Q3 = df_numeric[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df_numeric[(df_numeric[col] < lower_bound) | (df_numeric[col] > upper_bound)][col]
    print(f"{col}: {len(outliers)} outliers ({len(outliers)/len(df_numeric)*100:.2f}%)")
# Out:
#  NUMERICAL VARIABLES ANALYSIS
# ...
#  OUTLIER DETECTION (IQR Method):
# ------------------------------
# Unnamed: 0: 0 outliers (0.00%)
# IQ: 110 outliers (1.10%)
# Prev_Sem_Result: 788 outliers (7.88%)
# CGPA: 783 outliers (7.83%)
# Academic_Performance: 779 outliers (7.79%)
# Extra_Curricular_Score: 783 outliers (7.83%)
# Communication_Skills: 786 outliers (7.86%)
# Projects_Completed: 783 outliers (7.83%)

# %%
df['Placement'] = pd.get_dummies(df['Placement'], drop_first=True)

# %%
df.head(10)
# Out:
#    Unnamed: 0     IQ  Prev_Sem_Result  CGPA  Academic_Performance  \
# 0           0  107.0             6.61  6.28                   8.0
# 1           1   97.0             5.52  5.37                   8.0
# 2           2  100.0             5.36  5.83                   9.0
# 3           3  100.0             5.47  5.75                   6.0
# 4           4   96.0             7.91  7.69                   7.0
# 5           5   96.0             5.26  5.32                   7.0
# 6           6  123.0             6.68  6.58                   5.0
# 7           7  111.0             8.77  8.76                   7.0
# 8           8   92.0             6.47  6.33                   9.0
# 9           9  108.0             8.82  8.60                   4.0
#
#   Internship_Experience  Extra_Curricular_Score  Communication_Skills  \
# 0                    No                     8.0                   8.0
# 1                    No                   100.0                 100.0
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import roc_auc_score

x = df.drop('Placement', axis=1)
y = df['Placement']

categorical_cols = x.select_dtypes(include='object').columns
x = pd.get_dummies(x, columns=categorical_cols, drop_first=True)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)


rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(x_train, y_train)

y_pred = rf.predict(x_test)

print(classification_report(y_test, y_pred))

auc_score = roc_auc_score(y_test, y_pred)
print(f"AUC Score: {auc_score}")

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98      1709
#         True       0.87      0.90      0.88       291
#
#     accuracy                           0.96      2000
#    macro avg       0.92      0.94      0.93      2000
# weighted avg       0.97      0.96      0.97      2000
#
# AUC Score: 0.9367508581011383

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score
x = df.drop('Placement', axis=1)
y = df['Placement']

categorical_cols = x.select_dtypes(include='object').columns
x = pd.get_dummies(x, columns=categorical_cols, drop_first=True)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
lg = LogisticRegression(solver='liblinear', random_state=42)
lg.fit(x_train, y_train)
y_pred = lg.predict(x_test)
print(classification_report(y_test, y_pred))
auc_score = roc_auc_score(y_test, y_pred)
print(f"AUC Score: {auc_score}")

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        False       0.85      1.00      0.92      1709
#         True       0.00      0.00      0.00       291
#
#     accuracy                           0.85      2000
#    macro avg       0.43      0.50      0.46      2000
# weighted avg       0.73      0.85      0.79      2000
#
# AUC Score: 0.5
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.12/dist-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
from xgboost import XGBClassifier

x = df.drop('Placement', axis=1)
y = df['Placement']


categorical_cols = x.select_dtypes(include='object').columns
x = pd.get_dummies(x, columns=categorical_cols, drop_first=True)

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

XG = XGBClassifier(random_state=42)

XG.fit(x_train, y_train)
y_pred = XG.predict(x_test)
print(classification_report(y_test, y_pred))

auc_score = roc_auc_score(y_test, y_pred)
print(f"AUC Score: {auc_score}")


cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#        False       0.98      0.98      0.98      1709
#         True       0.86      0.90      0.88       291
#
#     accuracy                           0.96      2000
#    macro avg       0.92      0.94      0.93      2000
# weighted avg       0.97      0.96      0.97      2000
#
# AUC Score: 0.9396021467106624

# %%
### LogisticRegressia i jamanak warning e gcum qani vor hashvum em precision,recall,f1-score vori jamanak el bajanvum e 0  vra
### Modelneric kntrem XGboost y qani vor Auc Scory aveli bardzr e cuyc tali qan RandomForesty
### Unem outlierner bayc chem jnjum qani vor mec popoxutyun chi talu
